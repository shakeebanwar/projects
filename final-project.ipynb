# %%
print('--------------------------------------------')
print("   WELCOME TO RENTAL CAR MANAGMENT SYSTEM     ")
print('--------------------------------------------')
print('1 LOGIN\n2 REGISTER')
print('--------------------------------------------')
u1=""
p1=""
n=int(input("Enter your choice "))
def func():
    while n==1:
        u=input("ENTER YOUR USER-NAME ")
        p=input("ENTER YOUR PASSWORD ")
        if u=='shakeeb' and p=='12345' or u==u1 and p==p1 :
            print('login sucess')
            print('----------------')
            print('CHOOSE YOUR CAR WHERE YOU NEED TO RENT')
            print("1 NAME : TOYOTA-CORROLA\nCOLOR WHITE\nMODEL 2017\nRUNNING_KPH 1000\nPER_DAY 1000")
            print('-----------------------------------------------------------------')
            print("2 NAME : HONDA-CIVIC\nCOLOR Black\nMODEL 2018\nRUNNING_KPH 500\nPER_DAY 1500")
            print('-----------------------------------------------------------------')
            print("3 NAME : TOYOTA-PEJARO-V1\nCOLOR WHITE\nMODEL 2019\nRUNNING_KPH 50\nPER_DAY 4000")
            print('-----------------------------------------------------------------')
            print("4 NAME : TOYATA-MIRA\nCOLOR SILVER\nMODEL 2018\nRUNNING_KPH 500\nPER_DAY 1000")
            print('-----------------------------------------------------------------')
            print("5 NAME : SUZUKI-WAGENOR\nCOLOR GRAY\nMODEL 2017\nRUNNING_KPH 500\nPER_DAY 1300")
            chose=int(input("PLEASE CHOOSE YOUR CAR 1 FOR CORROLA 2 FOR HONDA 3 FOR PEJARO 4 FOR MIRA 5 FOR WAGENOR "))
            print('-----------------------------------------------------------------')
            if chose==1:
                print("YOU HAVE SUCESSFULLY RENT THIS CORROLA ")
                break
                
                
                
                #import a
                #a.car_details1()
            elif chose==2:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS HONDA-CIVIC ")
                break
                
           
            elif chose==3:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS PEJARO")
                break
                
            elif chose==4:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS MIRA ")
                break
                
            elif chose==5:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS WAGENOR ")
                break
                
            
            else:
                print('please Enter valid number ')
                break
    else:
        print('ENTER A VALID CHOICE')
                
            
func()
# Out:
# --------------------------------------------
#    WELCOME TO RENTAL CAR MANAGMENT SYSTEM
# --------------------------------------------
# 1 LOGIN
# 2 REGISTER
# --------------------------------------------
# Enter your choice 1
# ENTER YOUR USER-NAME shakeeb
# ENTER YOUR PASSWORD 12345
# login sucess
# ----------------
# CHOOSE YOUR CAR WHERE YOU NEED TO RENT
# 1 NAME : TOYOTA-CORROLA
# COLOR WHITE
# MODEL 2017
# RUNNING_KPH 1000
# PER_DAY 1000
# -----------------------------------------------------------------
# 2 NAME : HONDA-CIVIC
# COLOR Black
# MODEL 2018
# RUNNING_KPH 500
# PER_DAY 1500
# -----------------------------------------------------------------
# 3 NAME : TOYOTA-PEJARO-V1
# COLOR WHITE
# MODEL 2019
# RUNNING_KPH 50
# PER_DAY 4000
# -----------------------------------------------------------------
# 4 NAME : TOYATA-MIRA
# COLOR SILVER
# MODEL 2018
# RUNNING_KPH 500
# PER_DAY 1000
# -----------------------------------------------------------------
# ...

# %%
print('--------------------------------------------')
print("   WELCOME TO RENTAL CAR MANAGMENT SYSTEM     ")
print('--------------------------------------------')
print('1 LOGIN\n2 REGISTER')
print('--------------------------------------------')
u1=""
p1=""
n=int(input("Enter your choice "))
def func():
    while n==True:
        u=input("ENTER YOUR USER-NAME ")
        p=input("ENTER YOUR PASSWORD ")
        if u=='shakeeb' and p=='12345' or u==u1 and p==p1 :
            print('login sucess')
            print('----------------')
            print('CHOOSE YOUR CAR WHERE YOU NEED TO RENT')
            print("1 NAME : TOYOTA-CORROLA\nCOLOR WHITE\nMODEL 2017\nRUNNING_KPH 1000\nPER_DAY 1000")
            print('-----------------------------------------------------------------')
            print("2 NAME : HONDA-CIVIC\nCOLOR Black\nMODEL 2018\nRUNNING_KPH 500\nPER_DAY 1500")
            print('-----------------------------------------------------------------')
            print("3 NAME : TOYOTA-PEJARO-V1\nCOLOR WHITE\nMODEL 2019\nRUNNING_KPH 50\nPER_DAY 4000")
            print('-----------------------------------------------------------------')
            print("4 NAME : TOYATA-MIRA\nCOLOR SILVER\nMODEL 2018\nRUNNING_KPH 500\nPER_DAY 1000")
            print('-----------------------------------------------------------------')
            print("5 NAME : SUZUKI-WAGENOR\nCOLOR GRAY\nMODEL 2017\nRUNNING_KPH 500\nPER_DAY 1300")
            chose=int(input("PLEASE CHOOSE YOUR CAR 1 FOR CORROLA 2 FOR HONDA 3 FOR PEJARO 4 FOR MIRA 5 FOR WAGENOR "))
            print('-----------------------------------------------------------------')
            if chose==1:
                print("YOU HAVE SUCESSFULLY RENT THIS CORROLA ")
                break
                
                
                
                #import a
                #a.car_details1()
            elif chose==2:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS HONDA-CIVIC ")
                break
                
           
            elif chose==3:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS PEJARO")
                break
                
            elif chose==4:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS MIRA ")
                break
                
            elif chose==5:
                #import b
                #b.car2()
                print("YOU HAVE SUCESSFULLY RENT THIS WAGENOR ")
                break
                
            
            else:
                print('please Enter valid number ')
                break
    else:
        print('ENTER A VALID CHOICE')
                
            
func()
# Out:
#   File "<ipython-input-5-4d4652ee2904>", line 61
#     break
#     ^
# IndentationError: unexpected indent
